# %%
import pandas as pd
import numpy as np
import warnings 
warnings.filterwarnings('ignore')

# %%
x = pd.read_csv(r"C:\Users\starm\OneDrive\Desktop\KGISL\DA & DS\Projects\Reinforcement Project 2 - PYTHON\Housing Dataset\housing.csv")
x
# Out:
#                  date         price  bedrooms  bathrooms  sqft_living  \
# 0     02/05/2014 0:00  3.130000e+05         3       1.50       1340.0
# 1     02/05/2014 0:00  2.384000e+06         5       2.50       3650.0
# 2     02/05/2014 0:00  3.420000e+05         3       2.00       1930.0
# 3     02/05/2014 0:00  4.200000e+05         3       2.25       2000.0
# 4     02/05/2014 0:00  5.500000e+05         4       2.50       1940.0
# ...               ...           ...       ...        ...          ...
# 4595  09/07/2014 0:00  3.081667e+05         3       1.75       1510.0
# 4596  09/07/2014 0:00  5.343333e+05         3       2.50       1460.0
# 4597  09/07/2014 0:00  4.169042e+05         3       2.50       3010.0
# 4598  10/07/2014 0:00  2.034000e+05         4       2.00       2090.0
# 4599  10/07/2014 0:00  2.206000e+05         3       2.50       1490.0
#
#       sqft_lot  floors  waterfront  view  condition  sqft_above  \
# 0          NaN     1.5           0     0          3        1340
# 1          NaN     2.0           0     4          5        3370
# 2          NaN     1.0           0     0          4        1930
# 3          NaN     1.0           0     0          4        1000
# 4          NaN     1.0           0     0          4        1140
# ...        ...     ...         ...   ...        ...         ...
# 4595    6360.0     1.0           0     0          4        1510
# 4596    7573.0     2.0           0     0          3        1460
# 4597    7014.0     2.0           0     0          3        3010
# 4598    6630.0     1.0           0     0          3        1070
# 4599    8102.0     2.0           0     0          4        1490
#
#       sqft_basement  yr_built  yr_renovated                    street  \
# 0                 0    1955.0          2005      18810 Densmore Ave N
# 1               280    1921.0             0           709 W Blaine St
# 2                 0    1966.0             0  26206-26214 143rd Ave SE
# 3              1000    1963.0             0           857 170th Pl NE
# 4               800    1976.0          1992         9105 170th Ave NE
# ...             ...       ...           ...                       ...
# 4595              0       NaN          1979            501 N 143rd St
# 4596              0       NaN          2009          14855 SE 10th Pl
# 4597              0       NaN             0          759 Ilwaco Pl NE
# 4598           1020       NaN             0         5148 S Creston St
# 4599              0       NaN             0         18717 SE 258th St
#
#            city  statezip country
# 0     Shoreline  WA 98133     USA
# 1       Seattle  WA 98119     USA
# 2          Kent  WA 98042     USA
# 3      Bellevue  WA 98008     USA
# 4       Redmond  WA 98052     USA
# ...         ...       ...     ...
# 4595    Seattle  WA 98133     USA
# 4596   Bellevue  WA 98007     USA
# 4597     Renton  WA 98059     USA
# 4598    Seattle  WA 98178     USA
# 4599  Covington  WA 98042     USA
#
# [4600 rows x 18 columns]

# %%
house_set = x.copy()
house_set
# Out:
#                  date         price  bedrooms  bathrooms  sqft_living  \
# 0     02/05/2014 0:00  3.130000e+05         3       1.50       1340.0
# 1     02/05/2014 0:00  2.384000e+06         5       2.50       3650.0
# 2     02/05/2014 0:00  3.420000e+05         3       2.00       1930.0
# 3     02/05/2014 0:00  4.200000e+05         3       2.25       2000.0
# 4     02/05/2014 0:00  5.500000e+05         4       2.50       1940.0
# ...               ...           ...       ...        ...          ...
# 4595  09/07/2014 0:00  3.081667e+05         3       1.75       1510.0
# 4596  09/07/2014 0:00  5.343333e+05         3       2.50       1460.0
# 4597  09/07/2014 0:00  4.169042e+05         3       2.50       3010.0
# 4598  10/07/2014 0:00  2.034000e+05         4       2.00       2090.0
# 4599  10/07/2014 0:00  2.206000e+05         3       2.50       1490.0
#
#       sqft_lot  floors  waterfront  view  condition  sqft_above  \
# 0          NaN     1.5           0     0          3        1340
# 1          NaN     2.0           0     4          5        3370
# 2          NaN     1.0           0     0          4        1930
# 3          NaN     1.0           0     0          4        1000
# 4          NaN     1.0           0     0          4        1140
# ...        ...     ...         ...   ...        ...         ...
# 4595    6360.0     1.0           0     0          4        1510
# 4596    7573.0     2.0           0     0          3        1460
# 4597    7014.0     2.0           0     0          3        3010
# 4598    6630.0     1.0           0     0          3        1070
# 4599    8102.0     2.0           0     0          4        1490
#
#       sqft_basement  yr_built  yr_renovated                    street  \
# 0                 0    1955.0          2005      18810 Densmore Ave N
# 1               280    1921.0             0           709 W Blaine St
# 2                 0    1966.0             0  26206-26214 143rd Ave SE
# 3              1000    1963.0             0           857 170th Pl NE
# 4               800    1976.0          1992         9105 170th Ave NE
# ...             ...       ...           ...                       ...
# 4595              0       NaN          1979            501 N 143rd St
# 4596              0       NaN          2009          14855 SE 10th Pl
# 4597              0       NaN             0          759 Ilwaco Pl NE
# 4598           1020       NaN             0         5148 S Creston St
# 4599              0       NaN             0         18717 SE 258th St
#
#            city  statezip country
# 0     Shoreline  WA 98133     USA
# 1       Seattle  WA 98119     USA
# 2          Kent  WA 98042     USA
# 3      Bellevue  WA 98008     USA
# 4       Redmond  WA 98052     USA
# ...         ...       ...     ...
# 4595    Seattle  WA 98133     USA
# 4596   Bellevue  WA 98007     USA
# 4597     Renton  WA 98059     USA
# 4598    Seattle  WA 98178     USA
# 4599  Covington  WA 98042     USA
#
# [4600 rows x 18 columns]

# %%
house_set.head()
# Out:
#               date      price  bedrooms  bathrooms  sqft_living  sqft_lot  \
# 0  02/05/2014 0:00   313000.0         3       1.50       1340.0       NaN
# 1  02/05/2014 0:00  2384000.0         5       2.50       3650.0       NaN
# 2  02/05/2014 0:00   342000.0         3       2.00       1930.0       NaN
# 3  02/05/2014 0:00   420000.0         3       2.25       2000.0       NaN
# 4  02/05/2014 0:00   550000.0         4       2.50       1940.0       NaN
#
#    floors  waterfront  view  condition  sqft_above  sqft_basement  yr_built  \
# 0     1.5           0     0          3        1340              0    1955.0
# 1     2.0           0     4          5        3370            280    1921.0
# 2     1.0           0     0          4        1930              0    1966.0
# 3     1.0           0     0          4        1000           1000    1963.0
# 4     1.0           0     0          4        1140            800    1976.0
#
#    yr_renovated                    street       city  statezip country
# 0          2005      18810 Densmore Ave N  Shoreline  WA 98133     USA
# 1             0           709 W Blaine St    Seattle  WA 98119     USA
# 2             0  26206-26214 143rd Ave SE       Kent  WA 98042     USA
# 3             0           857 170th Pl NE   Bellevue  WA 98008     USA
# 4          1992         9105 170th Ave NE    Redmond  WA 98052     USA

# %%
house_set.tail()
# Out:
#                  date        price  bedrooms  bathrooms  sqft_living  \
# 4595  09/07/2014 0:00  308166.6667         3       1.75       1510.0
# 4596  09/07/2014 0:00  534333.3333         3       2.50       1460.0
# 4597  09/07/2014 0:00  416904.1667         3       2.50       3010.0
# 4598  10/07/2014 0:00  203400.0000         4       2.00       2090.0
# 4599  10/07/2014 0:00  220600.0000         3       2.50       1490.0
#
#       sqft_lot  floors  waterfront  view  condition  sqft_above  \
# 4595    6360.0     1.0           0     0          4        1510
# 4596    7573.0     2.0           0     0          3        1460
# 4597    7014.0     2.0           0     0          3        3010
# 4598    6630.0     1.0           0     0          3        1070
# 4599    8102.0     2.0           0     0          4        1490
#
#       sqft_basement  yr_built  yr_renovated             street       city  \
# 4595              0       NaN          1979     501 N 143rd St    Seattle
# 4596              0       NaN          2009   14855 SE 10th Pl   Bellevue
# 4597              0       NaN             0   759 Ilwaco Pl NE     Renton
# 4598           1020       NaN             0  5148 S Creston St    Seattle
# 4599              0       NaN             0  18717 SE 258th St  Covington
#
#       statezip country
# 4595  WA 98133     USA
# 4596  WA 98007     USA
# 4597  WA 98059     USA
# 4598  WA 98178     USA
# 4599  WA 98042     USA

# %%
house_set.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4600 entries, 0 to 4599
# Data columns (total 18 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   date           4600 non-null   object
#  1   price          4600 non-null   float64
#  2   bedrooms       4600 non-null   int64
#  3   bathrooms      4600 non-null   float64
#  4   sqft_living    4560 non-null   float64
#  5   sqft_lot       4586 non-null   float64
#  6   floors         4600 non-null   float64
#  7   waterfront     4600 non-null   int64
#  8   view           4600 non-null   int64
#  9   condition      4600 non-null   int64
#  10  sqft_above     4600 non-null   int64
#  11  sqft_basement  4600 non-null   int64
#  12  yr_built       4577 non-null   float64
#  13  yr_renovated   4600 non-null   int64
#  14  street         4600 non-null   object
#  15  city           4543 non-null   object
#  16  statezip       4600 non-null   object
#  17  country        4600 non-null   object
# dtypes: float64(6), int64(7), object(5)
# memory usage: 647.0+ KB

# %%
house_set.describe()
# Out:
#               price     bedrooms    bathrooms   sqft_living      sqft_lot  \
# count  4.600000e+03  4600.000000  4600.000000   4560.000000  4.586000e+03
# mean   5.539483e+05     3.400870     2.160815   2138.935526  1.485981e+04
# std    5.808371e+05     0.908848     0.783781    965.011449  3.592050e+04
# min    0.000000e+00     0.000000     0.000000    370.000000  6.380000e+02
# 25%    3.225000e+05     3.000000     1.750000   1460.000000  5.000000e+03
# 50%    4.610000e+05     3.000000     2.250000   1980.000000  7.683500e+03
# 75%    6.550000e+05     4.000000     2.500000   2620.000000  1.101850e+04
# max    2.659000e+07     9.000000     8.000000  13540.000000  1.074218e+06
#
#             floors   waterfront         view    condition    sqft_above  \
# count  4600.000000  4600.000000  4600.000000  4600.000000   4600.000000
# mean      1.512065     0.007174     0.240652     3.451739   1840.825435
# std       0.538288     0.084404     0.778405     0.677230    970.705795
# min       1.000000     0.000000     0.000000     1.000000    350.000000
# 25%       1.000000     0.000000     0.000000     3.000000   1190.000000
# 50%       1.500000     0.000000     0.000000     3.000000   1590.000000
# 75%       2.000000     0.000000     0.000000     4.000000   2300.000000
# max       3.500000     1.000000     4.000000     5.000000  20450.000000
#
#        sqft_basement     yr_built  yr_renovated
# count    4600.000000  4577.000000   4600.000000
# mean      312.081522  1970.808827    808.608261
# std       464.137228    29.724793    979.414536
# min         0.000000  1900.000000      0.000000
# 25%         0.000000  1951.000000      0.000000
# 50%         0.000000  1976.000000      0.000000
# 75%       610.000000  1997.000000   1999.000000
# max      4820.000000  2014.000000   2014.000000

# %%
house_set.isnull().sum()
# Out:
# date              0
# price             0
# bedrooms          0
# bathrooms         0
# sqft_living      40
# sqft_lot         14
# floors            0
# waterfront        0
# view              0
# condition         0
# sqft_above        0
# sqft_basement     0
# yr_built         23
# yr_renovated      0
# street            0
# city             57
# statezip          0
# country           0
# dtype: int64

# %%
#we check the overall null is presenting in the data

house_set.isnull().sum().sum()
# Out:
# 134

# %%
#To fill the missing null values in sqft_living, sqft_lot, yr_built(numeric values)

house_set['sqft_living'].fillna(house_set['sqft_living'].median(), inplace = True)
house_set['sqft_lot'].fillna(house_set['sqft_lot'].median(), inplace = True)
house_set['yr_built'].fillna(house_set['yr_built'].median(), inplace = True)
house_set
# Out:
#                  date         price  bedrooms  bathrooms  sqft_living  \
# 0     02/05/2014 0:00  3.130000e+05         3       1.50       1340.0
# 1     02/05/2014 0:00  2.384000e+06         5       2.50       3650.0
# 2     02/05/2014 0:00  3.420000e+05         3       2.00       1930.0
# 3     02/05/2014 0:00  4.200000e+05         3       2.25       2000.0
# 4     02/05/2014 0:00  5.500000e+05         4       2.50       1940.0
# ...               ...           ...       ...        ...          ...
# 4595  09/07/2014 0:00  3.081667e+05         3       1.75       1510.0
# 4596  09/07/2014 0:00  5.343333e+05         3       2.50       1460.0
# 4597  09/07/2014 0:00  4.169042e+05         3       2.50       3010.0
# 4598  10/07/2014 0:00  2.034000e+05         4       2.00       2090.0
# 4599  10/07/2014 0:00  2.206000e+05         3       2.50       1490.0
#
#       sqft_lot  floors  waterfront  view  condition  sqft_above  \
# 0       7683.5     1.5           0     0          3        1340
# 1       7683.5     2.0           0     4          5        3370
# 2       7683.5     1.0           0     0          4        1930
# 3       7683.5     1.0           0     0          4        1000
# 4       7683.5     1.0           0     0          4        1140
# ...        ...     ...         ...   ...        ...         ...
# 4595    6360.0     1.0           0     0          4        1510
# 4596    7573.0     2.0           0     0          3        1460
# 4597    7014.0     2.0           0     0          3        3010
# 4598    6630.0     1.0           0     0          3        1070
# 4599    8102.0     2.0           0     0          4        1490
#
#       sqft_basement  yr_built  yr_renovated                    street  \
# 0                 0    1955.0          2005      18810 Densmore Ave N
# 1               280    1921.0             0           709 W Blaine St
# 2                 0    1966.0             0  26206-26214 143rd Ave SE
# 3              1000    1963.0             0           857 170th Pl NE
# 4               800    1976.0          1992         9105 170th Ave NE
# ...             ...       ...           ...                       ...
# 4595              0    1976.0          1979            501 N 143rd St
# 4596              0    1976.0          2009          14855 SE 10th Pl
# 4597              0    1976.0             0          759 Ilwaco Pl NE
# 4598           1020    1976.0             0         5148 S Creston St
# 4599              0    1976.0             0         18717 SE 258th St
#
#            city  statezip country
# 0     Shoreline  WA 98133     USA
# 1       Seattle  WA 98119     USA
# 2          Kent  WA 98042     USA
# 3      Bellevue  WA 98008     USA
# 4       Redmond  WA 98052     USA
# ...         ...       ...     ...
# 4595    Seattle  WA 98133     USA
# 4596   Bellevue  WA 98007     USA
# 4597     Renton  WA 98059     USA
# 4598    Seattle  WA 98178     USA
# 4599  Covington  WA 98042     USA
#
# [4600 rows x 18 columns]

# %%
house_set['city'] = house_set['city'].fillna(house_set['city'].mode()[0])
house_set
# Out:
#                  date         price  bedrooms  bathrooms  sqft_living  \
# 0     02/05/2014 0:00  3.130000e+05         3       1.50       1340.0
# 1     02/05/2014 0:00  2.384000e+06         5       2.50       3650.0
# 2     02/05/2014 0:00  3.420000e+05         3       2.00       1930.0
# 3     02/05/2014 0:00  4.200000e+05         3       2.25       2000.0
# 4     02/05/2014 0:00  5.500000e+05         4       2.50       1940.0
# ...               ...           ...       ...        ...          ...
# 4595  09/07/2014 0:00  3.081667e+05         3       1.75       1510.0
# 4596  09/07/2014 0:00  5.343333e+05         3       2.50       1460.0
# 4597  09/07/2014 0:00  4.169042e+05         3       2.50       3010.0
# 4598  10/07/2014 0:00  2.034000e+05         4       2.00       2090.0
# 4599  10/07/2014 0:00  2.206000e+05         3       2.50       1490.0
#
#       sqft_lot  floors  waterfront  view  condition  sqft_above  \
# 0       7683.5     1.5           0     0          3        1340
# 1       7683.5     2.0           0     4          5        3370
# 2       7683.5     1.0           0     0          4        1930
# 3       7683.5     1.0           0     0          4        1000
# 4       7683.5     1.0           0     0          4        1140
# ...        ...     ...         ...   ...        ...         ...
# 4595    6360.0     1.0           0     0          4        1510
# 4596    7573.0     2.0           0     0          3        1460
# 4597    7014.0     2.0           0     0          3        3010
# 4598    6630.0     1.0           0     0          3        1070
# 4599    8102.0     2.0           0     0          4        1490
#
#       sqft_basement  yr_built  yr_renovated                    street  \
# 0                 0    1955.0          2005      18810 Densmore Ave N
# 1               280    1921.0             0           709 W Blaine St
# 2                 0    1966.0             0  26206-26214 143rd Ave SE
# 3              1000    1963.0             0           857 170th Pl NE
# 4               800    1976.0          1992         9105 170th Ave NE
# ...             ...       ...           ...                       ...
# 4595              0    1976.0          1979            501 N 143rd St
# 4596              0    1976.0          2009          14855 SE 10th Pl
# 4597              0    1976.0             0          759 Ilwaco Pl NE
# 4598           1020    1976.0             0         5148 S Creston St
# 4599              0    1976.0             0         18717 SE 258th St
#
#            city  statezip country
# 0     Shoreline  WA 98133     USA
# 1       Seattle  WA 98119     USA
# 2          Kent  WA 98042     USA
# 3      Bellevue  WA 98008     USA
# 4       Redmond  WA 98052     USA
# ...         ...       ...     ...
# 4595    Seattle  WA 98133     USA
# 4596   Bellevue  WA 98007     USA
# 4597     Renton  WA 98059     USA
# 4598    Seattle  WA 98178     USA
# 4599  Covington  WA 98042     USA
#
# [4600 rows x 18 columns]

# %%
#Again we check the any null is presenting in the data

house_set.isnull().sum()
# Out:
# date             0
# price            0
# bedrooms         0
# bathrooms        0
# sqft_living      0
# sqft_lot         0
# floors           0
# waterfront       0
# view             0
# condition        0
# sqft_above       0
# sqft_basement    0
# yr_built         0
# yr_renovated     0
# street           0
# city             0
# statezip         0
# country          0
# dtype: int64

# %%
set(house_set)
# Out:
# {'bathrooms',
#  'bedrooms',
#  'city',
#  'condition',
#  'country',
#  'date',
#  'floors',
#  'price',
#  'sqft_above',
#  'sqft_basement',
#  'sqft_living',
#  'sqft_lot',
#  'statezip',
#  'street',
#  'view',
#  'waterfront',
#  'yr_built',
#  'yr_renovated'}

# %%
house_set.shape
# Out:
# (4600, 18)

# %%
house_set.size
# Out:
# 82800

# %%
#Finding Duplicate values

dup_values = house_set.duplicated().sum()
print("No of Duplicate Values", dup_values)
# Out:
# No of Duplicate Values 0

# %%
house_set['date'] = pd.to_datetime(house_set['date'], errors='coerce')
house_set['date'] = house_set['date'].ffill()
house_set[['floors', 'price', 'bathrooms']] = house_set[['floors', 'price', 'bathrooms']].astype(int)

# %%
house_set.drop_duplicates()
# Out:
#            date    price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  \
# 0    2014-02-05   313000         3          1       1340.0    7683.5       1
# 1    2014-02-05  2384000         5          2       3650.0    7683.5       2
# 2    2014-02-05   342000         3          2       1930.0    7683.5       1
# 3    2014-02-05   420000         3          2       2000.0    7683.5       1
# 4    2014-02-05   550000         4          2       1940.0    7683.5       1
# ...         ...      ...       ...        ...          ...       ...     ...
# 4595 2014-09-07   308166         3          1       1510.0    6360.0       1
# 4596 2014-09-07   534333         3          2       1460.0    7573.0       2
# 4597 2014-09-07   416904         3          2       3010.0    7014.0       2
# 4598 2014-10-07   203400         4          2       2090.0    6630.0       1
# 4599 2014-10-07   220600         3          2       1490.0    8102.0       2
#
#       waterfront  view  condition  sqft_above  sqft_basement  yr_built  \
# 0              0     0          3        1340              0    1955.0
# 1              0     4          5        3370            280    1921.0
# 2              0     0          4        1930              0    1966.0
# 3              0     0          4        1000           1000    1963.0
# 4              0     0          4        1140            800    1976.0
# ...          ...   ...        ...         ...            ...       ...
# 4595           0     0          4        1510              0    1976.0
# 4596           0     0          3        1460              0    1976.0
# 4597           0     0          3        3010              0    1976.0
# 4598           0     0          3        1070           1020    1976.0
# 4599           0     0          4        1490              0    1976.0
#
#       yr_renovated                    street       city  statezip country
# 0             2005      18810 Densmore Ave N  Shoreline  WA 98133     USA
# 1                0           709 W Blaine St    Seattle  WA 98119     USA
# 2                0  26206-26214 143rd Ave SE       Kent  WA 98042     USA
# 3                0           857 170th Pl NE   Bellevue  WA 98008     USA
# 4             1992         9105 170th Ave NE    Redmond  WA 98052     USA
# ...            ...                       ...        ...       ...     ...
# 4595          1979            501 N 143rd St    Seattle  WA 98133     USA
# 4596          2009          14855 SE 10th Pl   Bellevue  WA 98007     USA
# 4597             0          759 Ilwaco Pl NE     Renton  WA 98059     USA
# 4598             0         5148 S Creston St    Seattle  WA 98178     USA
# 4599             0         18717 SE 258th St  Covington  WA 98042     USA
#
# [4600 rows x 18 columns]

# %%
#To change the datatype float into int to applying EDA

print("\n--------------SUMMARY STATISTICS-----------------\n")
print(house_set[["price", "bedrooms", "bathrooms", "sqft_living", "sqft_lot"]].describe().astype(int))
# Out:
# --------------SUMMARY STATISTICS-----------------
#
#           price  bedrooms  bathrooms  sqft_living  sqft_lot
# count      4600      4600       4600         4600      4600
# mean     553948         3          1         2137     14837
# std      580837         0          0          960     35867
# min           0         0          0          370       638
# 25%      322500         3          1         1470      5001
# 50%      461000         3          2         1980      7683
# 75%      655000         4          2         2610     11000
# max    26590000         9          8        13540   1074218

# %%
print("\n---------Exploratory Data Analysis (EDA)-----------\n")
print("\n---------Univariate Analysis-----------\n")

import seaborn as sns
import matplotlib.pyplot as plt

c = ['price', 'bedrooms', 'bathrooms', 'sqft_living', "sqft_lot" ]

for i in c:
    plt.figure(figsize =(6, 4))
    sns.histplot(house_set[i], kde=True, bins=30)
    plt.title(f"Distribution of {i}")
    plt.xlabel(i)
    plt.ylabel("Count")
    plt.show()
# Out:
# ---------Exploratory Data Analysis (EDA)-----------
#
#
# ---------Univariate Analysis-----------

# %%
print("\n---------Bivariate Analysis-----------\n")
sns.scatterplot(data=house_set, x = 'sqft_living', y = 'price')
plt.title("Price vs Sqft_Living")
plt.show()
# Out:
# ---------Bivariate Analysis-----------

# %%
avg_price = house_set.groupby('bedrooms')['price'].mean().reset_index()
plt.figure(figsize=(8, 5))
sns.barplot(x='bedrooms', y='price', data=avg_price)
plt.title('Average Price by Number of Bedrooms')
plt.xlabel('Number of Bedrooms')
plt.ylabel('Average Price')
plt.show()

# %%
print("\n---------Multi-variate Analysis-----------\n")
plt.figure(figsize=(10, 6))
correlations = house_set.corr(numeric_only=True)['price'].sort_values(ascending=False)
sns.barplot(x=correlations.index, y=correlations.values, palette="Set3")
plt.xticks(rotation=45)
plt.title("Correlation with Price")
plt.xlabel("Correlation Coefficient")
plt.grid(axis='y')
plt.tight_layout()
plt.show()
# Out:
# ---------Multi-variate Analysis-----------

# %%
print("\n---------Multi-variate Analysis-----------\n")
plt.figure(figsize=(10, 8))
sns.heatmap(house_set[['price', 'bedrooms', 'bathrooms', 'sqft_living', 'sqft_lot', 'floors']].corr(), annot=True, cmap='coolwarm')
plt.title('Correlation Heatmap')
plt.show()
# Out:
# ---------Multi-variate Analysis-----------

# %%
#Removing Outliers

def remove_outliers(house_set, column):
    Q1 = house_set[column].quantile(0.25)
    Q3 = house_set[column].quantile(0.75)
    
    IQR = Q3 - Q1
    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR
    
    return house_set[(house_set[column] >= lower_bound) & (house_set[column] <= upper_bound)]
    
x=["price","bedrooms","bathrooms","sqft_living","sqft_lot"]

for i in x:
    house_set = remove_outliers(house_set, i)

# %%
#boxplot for outliers
for i in x:
    plt.figure(figsize=(4, 3))
    sns.boxplot(y=house_set[i])
    plt.title(f'Boxplot of {i}')
    plt.ylabel(f'{i}')
    plt.show()

# %%
#Data Visualization

print("\n---------Data Visualization-----------\n")

sns.histplot(house_set['price'], bins=30, kde=True,color='orange')
plt.title('Distribution of House Prices')
plt.xlabel('Price')
plt.ylabel('Count')
plt.show()

sns.boxplot(x='bedrooms', y='price', data=house_set,color='green')
plt.title('Price Distribution by Number of Bedrooms')
plt.xlabel('Bedrooms')
plt.ylabel('Price')
plt.show()

sns.scatterplot(data=house_set, x='sqft_living', y='price',color='red')
plt.title('Price vs Sqft Living')
plt.xlabel('Sqft Living')
plt.ylabel('Price')
plt.show()


corr = house_set[['price', 'sqft_living', 'sqft_lot', 'bedrooms', 'bathrooms', 'floors']].corr()
sns.heatmap(corr, annot=True, cmap='coolwarm')
plt.title('Correlation Between Numeric Features')
plt.show()

sns.pairplot(house_set[['price', 'sqft_living', 'bedrooms', 'bathrooms']])
plt.suptitle('Pairwise Relationships', y=1.02)
plt.show()
# Out:
# ---------Data Visualization-----------

# %%
print("\n---------( PRICE TRENDS OVER TIME )-----------\n")

monthly_avg = house_set.groupby(house_set['date'].dt.to_period('M'))['price'].mean()
monthly_avg.plot(kind='line', figsize=(10, 5), marker='o')
plt.title('Monthly Average House Price Trend')
plt.xlabel('Month')
plt.ylabel('Average Price')
plt.grid(True)
plt.show()

sns.boxplot(data=house_set, x='bedrooms', y='price')
plt.title('Outliers in Price by Number of Bedrooms')
plt.xlabel('Bedrooms')
plt.ylabel('Price')
plt.show()

avg_price_city = house_set.groupby('city')['price'].mean().sort_values(ascending=False).head(10)
avg_price_city.plot(kind='bar', figsize=(10, 5), color='brown')
plt.title('Top 10 Cities by Average Price')
plt.xlabel('City')
plt.ylabel('Average Price')
plt.xticks(rotation=45)
plt.show()
# Out:
# ---------( PRICE TRENDS OVER TIME )-----------

# %%
# Feature Engineering
house_set['house_age'] = 2025 - house_set['yr_built']
house_set['renovated_age'] = house_set['yr_renovated'].apply(lambda x: 2025 - x if x > 0 else 0)
house_set['price_per_sqft'] = house_set['price'] / house_set['sqft_living']
house_set['total_sqft'] = house_set['sqft_living'] + house_set['sqft_basement']
house_set['bath_bed_ratio'] = house_set['bathrooms'] / house_set['bedrooms'].replace(0, 1)
house_set.dropna(inplace=True)

house_set.head()
# Out:
#         date   price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  \
# 0 2014-02-05  313000         3          1       1340.0    7683.5       1
# 2 2014-02-05  342000         3          2       1930.0    7683.5       1
# 3 2014-02-05  420000         3          2       2000.0    7683.5       1
# 4 2014-02-05  550000         4          2       1940.0    7683.5       1
# 5 2014-02-05  490000         2          1        880.0    7683.5       1
#
#    waterfront  view  condition  ...  yr_renovated                    street  \
# 0           0     0          3  ...          2005      18810 Densmore Ave N
# 2           0     0          4  ...             0  26206-26214 143rd Ave SE
# 3           0     0          4  ...             0           857 170th Pl NE
# 4           0     0          4  ...          1992         9105 170th Ave NE
# 5           0     0          3  ...          1994            522 NE 88th St
#
#         city  statezip country house_age renovated_age price_per_sqft  \
# 0  Shoreline  WA 98133     USA      70.0            20     233.582090
# 2       Kent  WA 98042     USA      59.0             0     177.202073
# 3   Bellevue  WA 98008     USA      62.0             0     210.000000
# 4    Redmond  WA 98052     USA      49.0            33     283.505155
# 5    Seattle  WA 98115     USA      87.0            31     556.818182
#
#    total_sqft  bath_bed_ratio
# 0      1340.0        0.333333
# 2      1930.0        0.666667
# 3      3000.0        0.666667
# 4      2740.0        0.500000
# 5       880.0        0.500000
#
# [5 rows x 23 columns]

# %%
from scipy import stats

# T-test: Waterfront vs Non-Waterfront
price_waterfront = house_set[house_set['waterfront'] == 1]['price']
price_non_waterfront = house_set[house_set['waterfront'] == 0]['price']

t_stat, p_val_ttest = stats.ttest_ind(price_waterfront, price_non_waterfront, equal_var=False)

print("T-test: Waterfront vs Non-Waterfront")
print(f"T-statistic = {t_stat:.3f}, p-value = {p_val_ttest:.5f}\n")


alpha = 0.05
if p_val_ttest < alpha:
    print("Result: Significant difference in price between waterfront and non-waterfront properties.")
else:
    print("Result: No significant difference in price between waterfront and non-waterfront properties.")


print("\n--------------------------------------------------------------------------------------------------n") 


# ANOVA: Price by Number of Bedrooms
grouped_prices = [group['price'].values for name, group in house_set.groupby('bedrooms')]
f_stat, p_val_anova = stats.f_oneway(*grouped_prices)

print("ANOVA: Price by Number of Bedrooms")
print(f"F-statistic = {f_stat:.3f}, p-value = {p_val_anova:.5e}\n")

# Interpretation of ANOVA
if p_val_anova < alpha:
    print("Result: At least one bedroom group has a significantly different mean price.")
else:
    print("Result: No significant difference in mean prices across bedroom groups.")
# Out:
# T-test: Waterfront vs Non-Waterfront
# T-statistic = 1.253, p-value = 0.26573
#
# Result: No significant difference in price between waterfront and non-waterfront properties.
#
# --------------------------------------------------------------------------------------------------n
# ANOVA: Price by Number of Bedrooms
# F-statistic = 99.389, p-value = 7.28837e-62
#
# Result: At least one bedroom group has a significantly different mean price.

# %%
#Project Insights

# %% [markdown]
# #Uni-variate Analysis Insights
#
# 1. Price Distribution
# The distribution of house prices is right-skewed.
#
# Most houses are priced between $200,000 and $600,000, with a sharp drop beyond that range.
#
# A few high-priced houses act as outliers.
#
# 2. Bedrooms
# The majority of homes have 3 bedrooms, followed by 4 bedrooms.
#
# Very few homes have 2 or 5 bedrooms.
#
# The distribution shows that the dataset is focused on standard residential properties.
#
# 3. Bathrooms
# Most homes have 1.0 or 2.0 bathrooms, forming clear peaks in the distribution.
#
# The distribution is multi-modal, showing several common configurations (e.g., 1, 1.5, 2 bathrooms).
#
# 4. sqft_living
# The distribution of sqft_living is right-skewed, indicating most homes are below 2500 sq. ft..
#
# Very large homes (above 3000 sq. ft.) are relatively rare.
#
# The bulk of homes fall between 1000 and 2500 sq. ft.
#
# 5. sqft_lot
# sqft_lot has a long tail, with most properties under 10,000 sq. ft., but a few going much higher.
#
# This suggests that while most homes are built on small to medium plots, there are a few large estates included.

# %%
#Bivariate Analysis Insights

# %% [markdown]
# 1. Price vs. Sqft_Living (Scatter Plot)
# There's a clear positive correlation between sqft_living and price.
#
# As the living area increases, the house price tends to increase.
#
# However, the spread becomes wider at higher square footages, indicating more price variation for larger homes.
#
# This supports the statistical finding: Pearson correlation = 0.419 (moderate positive).
#
# 2. Average Price by Number of Bedrooms (Bar Plot)
# Average price generally increases with the number of bedrooms from 1 to 8.
#
# Interestingly, houses with 0 bedrooms show an unusually high average price — possibly due to non-residential properties or studio-style premium listings.
#
# Beyond 8 bedrooms, the average price drops, which may reflect properties that are less desirable or located in non-premium areas.
#
# This supports your ANOVA test, which confirmed that bedroom count significantly affects price, but the relationship is not strictly linear.

# %%
#Multi-variate Analysis Insights

# %% [markdown]
# 1. Correlation Heatmap
# This chart shows pairwise correlation between key numerical features:
#
# Strongest correlation with price:
#
# sqft_living (0.58): Indicates a strong positive linear relationship with house price.
#
# bathrooms (0.36) and bedrooms (0.26) also show moderate correlation with price.
#
# sqft_lot has almost no correlation with price (−0.0097).
#
# floors and price correlation is weak (0.21), suggesting minimal influence.
#
# High correlation between sqft_living, bedrooms, and bathrooms shows that larger homes tend to have more rooms and bathrooms.
#
# 2. Bar Plot – Correlation of Features with Price
# This chart ranks variables based on their correlation with price.
#
# Top 3 positive influencers on price:
#
# sqft_living
#
# sqft_above
#
# bathrooms
#
# Features like yr_renovated, sqft_lot, and even waterfront have very low correlation, suggesting limited linear impact.
#
# Interestingly, view, condition, and floors show some effect, but not strong enough to predict price independently.

# %% [markdown]
# #Data Visualization Insights

# %% [markdown]
# 1. Distribution of House Prices
# House prices are right-skewed, with the highest concentration between $200,000 and $600,000.
#
# Few properties are priced above $1 million, indicating luxury home outliers.
#
# 2. Price Distribution by Number of Bedrooms (Boxplot)
# Median price increases slightly from 2 to 5 bedrooms.
#
# However, the spread (IQR) also increases, meaning greater price variability in homes with more bedrooms.
#
# Several outliers are present in every category, suggesting price is influenced by more than just bedroom count.
#
# 3. Price vs Sqft_Living (Scatter Plot)
# Clear positive linear trend: Larger homes (in sqft) generally command higher prices.
#
# This aligns with earlier correlation and regression findings (r ≈ 0.58).
#
# 4. Correlation Heatmap
# sqft_living, bathrooms, and bedrooms show moderate to strong positive correlation with price.
#
# sqft_lot shows almost no correlation, implying lot size has little direct impact on price in this dataset.
#
# sqft_living also strongly correlates with bedrooms and bathrooms, indicating feature overlap.
#
# 5. Pair Plot (Multivariate View)
# The pair plot confirms visual linear relationships between price, sqft_living, and bathrooms.
#
# Discrete variables like bedrooms form vertical clusters, showing they are not strongly continuous predictors.
#
# The scatter plots in the diagonal display non-normality in price and room counts.

# %% [markdown]
# #Insights for Price Trends & Regional Analysis

# %% [markdown]
# 1. Monthly Average House Price Trend (Line Plot)
# In 2014, average house prices declined steadily from January to July, hitting the lowest point in mid-year.
#
# A slight recovery is seen between August and December, but prices remained below January’s peak.
#
# This indicates seasonal trends or market corrections, with early-year pricing being higher.
#
# 2. Outliers in Price by Number of Bedrooms (Boxplot)
# All bedroom categories (2–5) have significant outliers on the higher end, indicating premium properties priced much above the median.
#
# The spread is wide for 3- and 4-bedroom homes, showing that homes in this range cater to diverse market segments (standard vs luxury).
#
# Despite more bedrooms, the median price doesn’t increase sharply, reinforcing that other features (like location and size) are stronger price drivers.
#
# 3. Top 10 Cities by Average Price (Bar Chart)
# Mercer Island, Clyde Hill, and Beaux Arts Village top the list, with average prices above $750,000.
#
# These cities are likely premium or waterfront zones with high property demand.
#
# Even the 10th-ranked city (Snoqualmie Pass) has a significantly higher average than the overall dataset mean, showing clear geographic price clustering.
